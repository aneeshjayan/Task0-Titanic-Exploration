# %% [markdown]
# <a href="https://colab.research.google.com/github/aneeshjayan/Task0-Titanic-Exploration/blob/main/task0_titanic_ANEESH%20JAYAN%20P_20bec1009.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
df= pd.read_csv ("/content/train.csv")
dr=pd.read_csv("/content/gender_submission.csv")
df1 = df.dropna(axis='columns') 
print(df1)
df1.drop(columns=['Name', 'PassengerId'])
ax = df.hist(column='Fare', bins=25, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)
ax1 = df.hist(column='Age', bins=25, grid=False, figsize=(12,8), color='#86bf92', zorder=2, rwidth=0.9)
ax = df.plot.bar(y='Survived', rot=0)
df2=df.loc[]
# Out:
#      PassengerId  Survived  Pclass  ... Parch            Ticket     Fare
# 0              1         0       3  ...     0         A/5 21171   7.2500
# 1              2         1       1  ...     0          PC 17599  71.2833
# 2              3         1       3  ...     0  STON/O2. 3101282   7.9250
# 3              4         1       1  ...     0            113803  53.1000
# 4              5         0       3  ...     0            373450   8.0500
# ..           ...       ...     ...  ...   ...               ...      ...
# 886          887         0       2  ...     0            211536  13.0000
# 887          888         1       1  ...     0            112053  30.0000
# 888          889         0       3  ...     2        W./C. 6607  23.4500
# 889          890         1       1  ...     0            111369  30.0000
# 890          891         0       3  ...     0            370376   7.7500
#
# [891 rows x 9 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df1=df.loc[20:80]
df1
# Out:
#     PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 20           21         0       2  ...  26.0000   NaN         S
# 21           22         1       2  ...  13.0000   D56         S
# 22           23         1       3  ...   8.0292   NaN         Q
# 23           24         1       1  ...  35.5000    A6         S
# 24           25         0       3  ...  21.0750   NaN         S
# ..          ...       ...     ...  ...      ...   ...       ...
# 76           77         0       3  ...   7.8958   NaN         S
# 77           78         0       3  ...   8.0500   NaN         S
# 78           79         1       2  ...  29.0000   NaN         S
# 79           80         1       3  ...  12.4750   NaN         S
# 80           81         0       3  ...   9.0000   NaN         S
#
# [61 rows x 12 columns]

# %%
df4=df.iloc[20:80]
df4
# Out:
#     PassengerId  Survived  Pclass  ...      Fare        Cabin  Embarked
# 20           21         0       2  ...   26.0000          NaN         S
# 21           22         1       2  ...   13.0000          D56         S
# 22           23         1       3  ...    8.0292          NaN         Q
# 23           24         1       1  ...   35.5000           A6         S
# 24           25         0       3  ...   21.0750          NaN         S
# 25           26         1       3  ...   31.3875          NaN         S
# 26           27         0       3  ...    7.2250          NaN         C
# 27           28         0       1  ...  263.0000  C23 C25 C27         S
# 28           29         1       3  ...    7.8792          NaN         Q
# 29           30         0       3  ...    7.8958          NaN         S
# 30           31         0       1  ...   27.7208          NaN         C
# 31           32         1       1  ...  146.5208          B78         C
# ...
